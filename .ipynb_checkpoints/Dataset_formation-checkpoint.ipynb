# %%
import pandas as pd
import os

# %%
# order of categories list matters
categories = ["APPLICATION","ANDROID_WEAR","ART_AND_DESIGN","AUTO_AND_VEHICLES","BEAUTY","BOOKS_AND_REFERENCE",
              "BUSINESS","COMICS","COMMUNICATION","DATING","ENTERTAINMENT","EVENTS","FINANCE",
              "FOOD_AND_DRINK","HEALTH_AND_FITNESS","HOUSE_AND_HOME","LIBRARIES_AND_DEMO","LIFESTYLE",
              "MAPS_AND_NAVIGATION","MEDICAL","MUSIC_AND_AUDIO","NEWS_AND_MAGAZINES","PARENTING","PERSONALIZATION",
              "PHOTOGRAPHY","PRODUCTIVITY","SHOPPING","SOCIAL","TOOLS","TRAVEL_AND_LOCAL","VIDEO_PLAYERS",
              "WEATHER","FAMILY_ACTION","FAMILY_BRAINGAMES","FAMILY_CREATE","FAMILY_EDUCATION","FAMILY_MUSICVIDEO",
              "FAMILY_PRETEND","FAMILY","GAME_ACTION","GAME_ADVENTURE","GAME_ARCADE","GAME_BOARD","GAME_CARD",
              "GAME_CASINO","GAME_CASUAL","GAME_EDUCATIONAL","GAME_MUSIC","GAME_PUZZLE","GAME_RACING","GAME_ROLE_PLAYING",
              "GAME_SIMULATION","GAME_SPORTS","GAME_STRATEGY","GAME_TRIVIA","GAME_WORD","EDUCATION","GAME","SPORTS",
              "GOOGLE_CAST","KIDS"]

collections = ["TOP_FREE","TOP_PAID","GROSSING","TRENDING", "NEW_FREE","NEW_PAID"]

# %%
data = []
for dirname, _, filenames in os.walk('./Data'):
    for filename in filenames:
        fileName = os.path.join(dirname, filename).split('\\')[-1] # Get the file name
        fileCat = ""
        fileColln = ""
        for cat in categories:
            if(cat in fileName):
                fileCat = cat
                break
        for colln in collections:
            if(colln in fileName):
                fileColln = colln
                break
        
        if(fileColln == ""):
            for colln in ["FREE", "PAID"]:
                if(colln in fileName):
                    fileColln = "TOP_" + colln
        
        df = pd.read_json(os.path.join(dirname, filename)) # read file
        df['category'] = fileCat
        df['grossing'] = 0
        df['trending'] = 0
            
        if(fileColln == 'GROSSING'):
            df['grossing'] = 1
        elif(fileColln == 'TRENDING'):
            df['trending'] = 1
        
        data.append(df.copy())

# %%
len(data)
# Out:
# 713

# %%
sum = 0
for i in data:
    sum+=len(i)
print(sum)
# Out:
# 154637

# %%
df = pd.DataFrame()
for i in data:
    df = pd.concat([df,i])

# %%
df.drop_duplicates(subset="appId",inplace=True)

# %%
df.to_csv('Dataset.csv',index=False)

# %%
dataset = pd.read_csv('Dataset.csv')

# %%
dataset
# Out:
#                                                   title  \
# 0             Strava: Track Running, Cycling & Swimming
# 1                         Calm - Meditate, Sleep, Relax
# 2         Any.do: To do list, Task, Reminders & Planner
# 3      Viber Messenger - Free Video Calls & Group Chats
# 4             Fitify: Workout Routines & Training Plans
# ...                                                 ...
# 57585                         Visage Weather for Kustom
# 57586                       KMW Flat Weather for Kustom
# 57587                         Androidlet Weather Widget
# 57588                                Metro Clock Widget
# 57589                     Beach GO Weather Widget Theme
#
#                                                  appId  \
# 0                                           com.strava
# 1                                     com.calm.android
# 2                                            com.anydo
# 3                                       com.viber.voip
# 4             com.fitifyworkouts.bodyweight.workoutapp
# ...                                                ...
# 57585                        visageweather.kustom.pack
# 57586                              kmwflat.kustom.pack
# 57587           com.androidlet.androidletweatherwidget
# 57588              upper.duper.widget.metro.clock.full
# 57589  com.gau.go.weatherex.systemwidgetskin.beachskin
#
#                                                      url  \
# 0      https://play.google.com/store/apps/details?id=...
# 1      https://play.google.com/store/apps/details?id=...
# 2      https://play.google.com/store/apps/details?id=...
# 3      https://play.google.com/store/apps/details?id=...
# 4      https://play.google.com/store/apps/details?id=...
# ...                                                  ...
# 57585  https://play.google.com/store/apps/details?id=...
# 57586  https://play.google.com/store/apps/details?id=...
# 57587  https://play.google.com/store/apps/details?id=...
# 57588  https://play.google.com/store/apps/details?id=...
# 57589  https://play.google.com/store/apps/details?id=...
#
#                                                     icon  \
# 0      https://play-lh.googleusercontent.com/j-ZV144P...
# 1      https://play-lh.googleusercontent.com/S76GphUu...
# 2      https://play-lh.googleusercontent.com/zgOLUXCH...
# 3      https://play-lh.googleusercontent.com/U6w6exKd...
# 4      https://play-lh.googleusercontent.com/w-J_dDOK...
# ...                                                  ...
# 57585  https://play-lh.googleusercontent.com/Zr7IjCLM...
# 57586  https://play-lh.googleusercontent.com/N8E1KZQE...
# 57587  https://play-lh.googleusercontent.com/OgemVK_O...
# 57588  https://play-lh.googleusercontent.com/-ERO6aOZ...
# 57589  https://play-lh.googleusercontent.com/j7tX8vBD...
#
#                              developer                      developerId  \
# 0                          Strava Inc.                      Strava+Inc.
# 1                       Calm.com, Inc.                   Calm.com,+Inc.
# 2         Any.do To-do list & Calendar              5304780265295461149
# 3                 Viber Media S.à r.l.              7446565317689230946
# 4               Fitify Workouts s.r.o.              8442910174173427613
# ...                                ...                              ...
# 57585                     Kev Mitchell              4854740142838553464
# 57586                     Kev Mitchell              4854740142838553464
# 57587  Chunyen Liu (a.k.a. Androidlet)  Chunyen+Liu+(a.k.a.+Androidlet)
# 57588                         Us Droid              9128974857334929787
# 57589                        Lucky Art                        Lucky+Art
#
#       priceText  price   free  \
# 0          FREE    0.0   True
# 1          FREE    0.0   True
# 2          FREE    0.0   True
# 3          FREE    0.0   True
# 4          FREE    0.0   True
# ...         ...    ...    ...
# 57585    ₹55.00   55.0  False
# 57586    ₹55.00   55.0  False
# 57587    ₹85.00   85.0  False
# 57588   ₹150.00  150.0  False
# 57589      FREE    0.0   True
#
#                                                  summary  scoreText     score  \
# 0      Activity tracker - Run, ride or swim with GPS:...        4.4  4.420740
# 1      Join the millions discovering the life-changin...        4.0  4.024002
# 2      To-do list &amp; Tasks ✅ Calendar  📅ֿ  Reminde...        4.4  4.350565
# 3      Enjoy the video, calling &amp; texting messeng...        4.4  4.384726
# 4      #1 workout app. Workout routines &amp; trainin...        4.6  4.577787
# ...                                                  ...        ...       ...
# 57585  Color-customizable weather icon komponent for ...        4.7  4.650000
# 57586  Color-customizable weather icon komponent for ...        5.0  5.000000
# 57587  widget to show current weather and next 3-day ...        4.0  4.000000
# 57588  City Clock Widget + Weather + Dynamic Backgrou...        4.0  3.984127
# 57589  Brand new FREE theme for GO Weather widgets. S...        4.5  4.525000
#
#       currency      category  grossing  trending
# 0          NaN  ANDROID_WEAR         1         0
# 1          NaN  ANDROID_WEAR         1         0
# 2          NaN  ANDROID_WEAR         1         0
# 3          NaN  ANDROID_WEAR         1         0
# 4          NaN  ANDROID_WEAR         1         0
# ...        ...           ...       ...       ...
# 57585        ₹       WEATHER         0         0
# 57586        ₹       WEATHER         0         0
# 57587        ₹       WEATHER         0         0
# 57588        ₹       WEATHER         0         0
# 57589      NaN       WEATHER         0         0
#
# [57590 rows x 16 columns]
