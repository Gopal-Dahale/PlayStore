# %%
import os
import shutil
import json

# %%
file = open('./fails.txt','r',encoding='utf-8')

# %%
skippedFiles = file.readlines()

# %%
len(skippedFiles)
# Out:
# 9747

# %%
c = 0
for i in skippedFiles:
    index = i.split(' ')[0]
    print(c,index)
    c+=1
    orig = r'./Edges_Basic/'+index+'.json'
    target = r'./SkippedFiles/'+index+'.json'
    shutil.copyfile(orig,target)
# Out:
# 0 774
# 1 917
# 2 1189
# 3 1252
# 4 1254
# 5 1694
# 6 1698
# 7 1701
# 8 2227
# 9 5684
# 10 6533
# 11 6541
# 12 6544
# 13 6548
# 14 6578
# 15 6639
# 16 6640
# 17 6753
# 18 6894
# 19 6969
# 20 7069
# 21 7089
# 22 7140
# 23 7204
# 24 7207
# 25 7236
# 26 7326
# 27 7383
# 28 7490
# 29 7553
# 30 7689
# 31 7762
# 32 7776
# 33 7823
# 34 7874
# 35 8036
# 36 8164
# 37 8228
# 38 8309
# 39 8351
# 40 8416
# 41 8529
# 42 8840
# 43 9228
# 44 10232
# 45 11054
# 46 11112
# 47 11370
# 48 11971
# 49 12019
# 50 12939
# 51 13371
# 52 13456
# 53 13517
# 54 13686
# 55 13966
# 56 14319
# 57 15034
# 58 15221
# 59 15618
# 60 16031
# 61 16116
# 62 16528
# 63 17081
# 64 17525
# 65 18109
# 66 19590
# 67 19756
# 68 20000
# 69 20242
# 70 20374
# 71 20837
# 72 20875
# 73 21409
# 74 22056
# 75 22559
# 76 22726
# 77 23287
# 78 23322
# 79 23434
# 80 23441
# 81 23673
# 82 23724
# 83 24091
# 84 24166
# 85 24879
# 86 25071
# 87 25170
# 88 25306
# 89 25525
# 90 25673
# 91 25820
# 92 25831
# 93 25994
# 94 25997
# 95 26046
# ...
